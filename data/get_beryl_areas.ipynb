# %%
import iblatlas as atlas
from iblatlas.atlas import AllenAtlas

# %%
from iblatlas.regions import BrainRegions

br = BrainRegions()

# %%
import numpy as np
cosmos_indices = np.unique(br.mappings['Cosmos'])
br.acronym[cosmos_indices]
# Out:
# array(['void', 'root', 'Isocortex', 'OLF', 'HPF', 'CTXsp', 'CNU', 'TH',
#        'HY', 'MB', 'HB', 'CB'], dtype=object)

# %%
cosmos_indices
# Out:
# array([   0,    1,    6,  380,  455,  556,  571,  642,  716,  807,  883,
#        1015], dtype=int64)

# %%
areas = [
        'MO', 'ORB', 'VIS', 'PIR', 'CTXsp', 'CA1', 'SUB', 'CA3',
        'DG', 'cc', 'VPM', 'VPL', 'PO', 'CP', 'ACB', 'MB']

# %%
acronyms, indexes = brain_regions.acronym2index(areas)

# %%
indexes
# Out:
# [array([  13, 1340], dtype=int64),
#  array([ 253, 1580], dtype=int64),
#  array([ 158, 1485], dtype=int64),
#  array([ 417, 1744], dtype=int64),
#  array([ 556, 1883], dtype=int64),
#  array([ 458, 1785], dtype=int64),
#  array([ 536, 1863], dtype=int64),
#  array([ 468, 1795], dtype=int64),
#  array([ 474, 1801], dtype=int64),
#  array([1192, 2519], dtype=int64),
#  array([ 650, 1977], dtype=int64),
#  array([ 648, 1975], dtype=int64),
#  array([ 670, 1997], dtype=int64),
#  array([ 574, 1901], dtype=int64),
#  array([ 576, 1903], dtype=int64),
#  array([ 807, 2134], dtype=int64)]

# %%
def rgb_to_hex(rgb):
    r,g,b = rgb
    return '#{:02x}{:02x}{:02x}'.format(r, g, b)

# %%
hexes = []
for tup in indexes:
    hexes.append(rgb_to_hex(brain_regions.rgb[tup[0]]))

# %%
len(hexes)
# Out:
# 15

# %%
len(areas)
# Out:
# 16

# %%
len(indexes)
# Out:
# 15

# %%
hexes
# Out:
# ['#1f9d5a',
#  '#248a5e',
#  '#08858c',
#  '#6acbba',
#  '#8ada87',
#  '#7ed04b',
#  '#4fc244',
#  '#7ed04b',
#  '#7ed04b',
#  '#cccccc',
#  '#ff8084',
#  '#ff8084',
#  '#ff909f',
#  '#98d6f9',
#  '#80cdf8',
#  '#ff64ff']
