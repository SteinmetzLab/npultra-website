# %%
import iblatlas as atlas

# %%
# Out:
# <module 'iblatlas' from 'c:\\Users\\Dan\\anaconda3\\envs\\iblenv\\lib\\site-packages\\iblatlas\\__init__.py'>

# %%
# Get the unique beryl areas from the full list of allen areas in the metadata file
